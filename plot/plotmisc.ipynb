# %% [markdown]
# # Misc plots

# %%
import pandas as pd
import plotnine as p9
p9.options.figure_size=(11,8)
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
now=datetime.now()
date=f'{now.year}-{now.month:02d}-{now.day:02d}'

# %% [markdown]
# ## Creative non-fiction

# %%
# Load job data
df_all = pd.read_csv('../synthesis/data.jobcensus.synthesized.2021-01-12.csv')
# Load field aliases
df_alias = pd.read_csv('../synthesis/data.jobcensus.field_aliases.csv')
# Merge
df = df_all.merge(df_alias,on='JobField',how='inner')
# Clean
df['JobYear']=df['JobYear'].apply(int)
df = df[df.FieldAlias!='--']
# Show
df
# Out:
#                                                 JobTitle  JobYear  \
# 0                 Bard College (Annandale-on-Hudson, NY)     2011
# 1                        Bowdoin College (Brunswick, ME)     2011
# 2                     Boston College (Chestnut Hill, MA)     2011
# 3                      Brown University (Providence, RI)     2011
# 4             Central Methodist University (Fayette, MO)     2011
# ...                                                  ...      ...
# 13979                         Associate Professor Poetry     2020
# 13980  Assistant Professor in Asian American, Pacific...     2020
# 13981  Visiting Faculty Position in Japanese at Benni...     2020
# 13982  Professorships in Race in Art & Design (Libera...     2020
# 13983                  Assistant Professor of Portuguese     2020
#
#                                                  JobLink  JobType  \
# 0                                                    NaN       TT
# 1                                                    NaN  Unknown
# 2                                                    NaN       TT
# 3               http://chronicle.com/jobs/0000646693-01/  Unknown
# 4      http://www.higheredjobs.com/faculty/details.cf...       TT
# ...                                                  ...      ...
# 13979  https://joblist.mla.org/job-details/2761/assoc...       TT
# 13980  https://joblist.mla.org/job-details/2685/assis...       TT
# 13981  https://joblist.mla.org/job-details/2699/visit...   Non-TT
# 13982  https://joblist.mla.org/job-details/2772/profe...       TT
# 13983  https://mlajoblist-js.madgexccstage.com/job-de...       TT
#
#                     JobField JobSource  \
# 0                   Medieval      Wiki
# 1                   Medieval      Wiki
# 2                   Medieval      Wiki
# 3                   Medieval      Wiki
# 4                   Medieval      Wiki
# ...                      ...       ...
# 13979                 Poetry       JIL
# 13980                  Asian       JIL
# 13981               Japanese       JIL
# 13982  Critical Race Studies       JIL
# 13983             Portuguese       JIL
#
#                                                  JobDesc  \
# 0      Position Title: Assistant Professor\nDescripti...
# 1      From MLA JIL (November 12)\nDescription: Two-y...
# 2      Position Title: Assistant Professor\nLink: on ...
# 3      LINK\nDescription: "full professor of English ...
# 4      Position Title: Tenure-track Assistant or Asso...
# ...                                                  ...
# 13979  University of California, Irvine | English | F...
# 13980        Atlanta, GA | English | Full-time | Georgia
# 13981  Bennington, VT | Japanese | Humanities | Part-...
# 13982  Providence, Rhode Island, United States, 02903...
# 13983  US Air Force Academy, Colorado Springs, CO | P...
#
#                                             JobLink_norm      FieldAlias  \
# 0                                                    NaN        Medieval
# 1                                                    NaN        Medieval
# 2                                                    NaN        Medieval
# 3               http://chronicle.com/jobs/0000646693-01/        Medieval
# 4      http://www.higheredjobs.com/faculty/details.cf...        Medieval
# ...                                                  ...             ...
# 13979           https://joblist.mla.org/job-details/2761          Poetry
# 13980           https://joblist.mla.org/job-details/2685  Ethnic Studies
# 13981           https://joblist.mla.org/job-details/2699       Languages
# 13982           https://joblist.mla.org/job-details/2772  Ethnic Studies
# 13983  https://mlajoblist-js.madgexccstage.com/job-de...       Languages
#
#        Count
# 0        202
# 1        202
# 2        202
# 3        202
# 4        202
# ...      ...
# 13979      2
# 13980      1
# 13981      1
# 13982      1
# 13983      1
#
# [13500 rows x 10 columns]

# %%
# Creative writing?
df['FieldAlias'].value_counts()
# Out:
# Postdoc                        2335
# Rhetoric/Composition           2156
# Creative Writing               1604
# Ethnic Studies                  819
# Generalist                      718
# Gender Studies                  695
# Theatre/Drama                   607
# Early Modern                    473
# Film Studies                    429
# Anglophone/Postcolonial         375
# Community Colleges              361
# Medieval                        354
# American: C19/Early             306
# British: Modern/Contemp.        295
# New Media and DH                274
# American: C20-C21               250
# British: C19                    245
# British: C17-C18                242
# Comparative Literature          239
# British Open                    150
# American Studies                145
# Children’s Lit                  141
# Languages                        80
# Communication/Media Studies      53
# Environmental Literature         47
# Regional                         33
# Jewish Studies                   27
# Critical Theory                  26
# Translation Studies              16
# Unknown                           4
# Poetry                            1
# Name: FieldAlias, dtype: int64

# %%
df_cw = df[df['FieldAlias'] == "Creative Writing"]
df_cw
# Out:
#                                                 JobTitle  JobYear  \
# 3877                Beloit College (Poetry VAP position)     2011
# 3878             Bowling Green SU (TT Asst Prof, Poetry)     2011
# 3879                                    Brown University     2011
# 3880         California State University, San Bernardino     2011
# 3881   Columbia College Chicago - Assistant Professor...     2011
# ...                                                  ...      ...
# 13150  Early Career Fellowship in Creative Writing: R...     2020
# 13151  Assistant Professor of English and Director of...     2020
# 13152               O'Connor Fellows in Creative Writing     2020
# 13153               Open Rank - English or Related Field     2020
# 13154  Tenure Track Assistant Professor - Creative Wr...     2020
#
#                                                  JobLink  JobType  \
# 3877                         mailto:bcenglish@beloit.edu   Non-TT
# 3878   http://www.higheredjobs.com/search/details.cfm...       TT
# 3879   http://www.higheredjobs.com/faculty/details.cf...       TT
# 3880                                                 NaN       TT
# 3881                       https://employment.colum.edu/       TT
# ...                                                  ...      ...
# 13150  https://joblist.mla.org/job-details/2877/early...  Postdoc
# 13151  https://joblist.mla.org/job-details/2799/assis...       TT
# 13152  https://joblist.mla.org/job-details/2822/o-con...  Postdoc
# 13153  https://joblist.mla.org/job-details/2717/open-...       TT
# 13154  https://joblist.mla.org/job-details/2694/tenur...       TT
#
#                JobField JobSource  \
# 3877    CreativeWriting      Wiki
# 3878    CreativeWriting      Wiki
# 3879    CreativeWriting      Wiki
# 3880    CreativeWriting      Wiki
# 3881    CreativeWriting      Wiki
# ...                 ...       ...
# 13150  Creative Writing       JIL
# 13151  Creative Writing       JIL
# 13152  Creative Writing       JIL
# 13153  Creative Writing       JIL
# 13154  Creative Writing       JIL
#
#                                                  JobDesc  \
# 3877   From MLA JIL (2/25)\n2 Visiting Assistant Prof...
# 3878   HigherEd\n"Tenure-track assistant professor in...
# 3879   Higher Ed\n"Brown University invites applicati...
# 3880   From MLA JIL\n"The English Department seeks a ...
# 3881   From MLA JIL 3/18/11:\nASSISTANT PROFESSOR OF ...
# ...                                                  ...
# 13150  Austin, TX | English | Full-time | Texas | Cre...
# 13151  High Point University - High Point, NC | Engli...
# 13152  Colgate University, Hamilton, NY | English | F...
# 13153  Washington, DC | English, American Sign Langua...
# 13154  Davis, California | English | Full-time | Cali...
#
#                                             JobLink_norm        FieldAlias  \
# 3877                         mailto:bcenglish@beloit.edu  Creative Writing
# 3878   http://www.higheredjobs.com/search/details.cfm...  Creative Writing
# 3879   http://www.higheredjobs.com/faculty/details.cf...  Creative Writing
# 3880                                                 NaN  Creative Writing
# 3881                       https://employment.colum.edu/  Creative Writing
# ...                                                  ...               ...
# 13150           https://joblist.mla.org/job-details/2877  Creative Writing
# 13151           https://joblist.mla.org/job-details/2799  Creative Writing
# 13152           https://joblist.mla.org/job-details/2822  Creative Writing
# 13153           https://joblist.mla.org/job-details/2717  Creative Writing
# 13154           https://joblist.mla.org/job-details/2694  Creative Writing
#
#        Count
# 3877    1039
# 3878    1039
# 3879    1039
# 3880    1039
# 3881    1039
# ...      ...
# 13150    215
# 13151    215
# 13152    215
# 13153    215
# 13154    215
#
# [1604 rows x 10 columns]

# %%
# Mark as creative non/fiction?
def mark_creative_nonfic(jobdesc):
    import re
    # lowercase
    jobdesc=str(jobdesc).lower().replace('non-fiction','nonfiction')
    rgx = re.compile("(\w[\w']*\w|\w)")
    jobdesc_words=set(rgx.findall(jobdesc))
    labeld = {
        'Non-Fiction':{'non-fiction','nonfiction'},
        'Fiction':{'fiction'},
        'Poetry':{'poetry'}
    }
    label = []
    for genre,lbls in labeld.items():
        if lbls & jobdesc_words:
            label.append(genre)
    labelstr='/'.join(label)
    if not labelstr: labelstr='Other'
    return labelstr

# %%
df_cw['cw_genre']=df_cw['JobDesc'].apply(mark_creative_nonfic)
df_cw['cw_genre_nonfiction']=df_cw['cw_genre'].apply(lambda x: 'Non-Fiction' if 'Non-Fiction' in x else 'Other')
df_cw['cw_genre_fiction']=df_cw['cw_genre'].apply(lambda x: 'Fiction' if 'Fiction' in x.replace('Non-Fiction','') else 'Other')
df_cw['cw_genre_poetry']=df_cw['cw_genre'].apply(lambda x: 'Poetry' if 'Poetry' in x else 'Other')
df_cw['cw_genre'].value_counts()
# Out:
# Fiction                       350
# Other                         300
# Poetry                        239
# Non-Fiction/Fiction/Poetry    226
# Non-Fiction/Fiction           186
# Non-Fiction                   126
# Fiction/Poetry                110
# Non-Fiction/Poetry             67
# Name: cw_genre, dtype: int64

# %%
# save
df_cw.to_csv('../synthesis/data.jobcensus.synthesized.2021-01-12.creative-writing.csv')

# %%
# Check
print(df_cw[df_cw['cw_genre']=='Non-Fiction'].JobDesc.sample(n=1).iloc[0])
# Out:
# Department: English & Comp Literature. Application Deadline: 11/15/2011 Recruitment ID: 2501821
# Position Summary: Entry-level, tenure-track position. Competitive salary for entry-level Assistant Professor; 2-2 teaching load, undergraduate classes.
# Education Requirements: BA (MFA preferred).
# Qualifications and Experience: Candidates must have established strong literary reputations, at the national and/or international level, in Creative Non-Fiction. Requirements include substantial, ongoing publication; at least two years college teaching experience; and commitment to teaching undergraduates and mentoring young writers. Candidates should also have at least one book in print.
# Special Instructions: Applicants must apply online at http://jobs.unc.edu/2501821 and electronically upload a letter of application, a current curriculum vitae, copies of reviews of recent books, and copies of relevant publications. Click on the Direct Link URL from any internet browser to apply for the position.
# Hard copies of recent books (at least one book in print required) and copies of relevant publications that cannot be uploaded electronically should be mailed to:
# Beverly Taylor, Chair
# Department of English and Comparative Literature
# Greenlaw Hall, CB# 3520
# UNC-Chapel Hill
# Chapel Hill, NC 27599-3520
# In addition, applicants should have four letters of recommendation sent to gtompkins@unc.edu.
# Inside Higher Ed
# Deadline: Nov. 15
# Acknowledgment received:
# Request for additional materials:
# Rejection (no interview):
# MLA or Phone interview scheduled:
# Rejection (after MLA or phone interview):
# Campus interview scheduled: (phone call) 1/27/12 x 2
# Rejection (after campus interview):
# Offer made: 3/1
# Offer accepted: 3/30
# NOTES:
# Anyone heard anything about this job??
# A: They seem to have skipped preliminary interviews and are scheduling campus visits for February.

# %%
# Check
print(df_cw[df_cw['cw_genre']=='Non-Fiction/Fiction'].JobDesc.sample(n=1).iloc[0])
# Out:
# Spelman College seeks teacher/scholars dedicated to excellence in teaching and to the continued enhancement of the academic environment for students and colleagues. Founded in 1881, Spelman College is a private four-year liberal arts college located in Atlanta, GA. The oldest historically Black college for women in the United States, Spelman is a member of the Atlanta University Center Consortium and Atlanta Regional Consortium for Higher Education. All tenure-track candidates are expected to have a demonstrated interest in liberal arts and sciences education, contribute effectively to undergraduate teaching, assist in curriculum development, provide service to the department and College, as well as be active in scholarly, creative, and/or research productivity appropriate to a liberal arts environment.
# Essential Duties and Responsibilities: The Department of English invites applications for an Assistant or Associate Professor of Creative Writing to begin August 2019. Must have MFA in Creative Writing or comparable professional experience. Responsibilities include teaching a 3-3 teaching load in the general education core, the English major, and the Writing/Creative Writing minor. Active department and college-level service is expected.
# MFA or comparable professional experience; College-level teaching experience
# Specializations in one or more of the following areas preferred: screenwriting, fiction, creative-nonfiction, and/or diasporic literatures.
# Online App. Form: https://spelman.peopleadmin.com
# HigherEdJobs.com
# Application Due: 11/16/2018.
# Acknowledgment received:
# Request for additional materials:
# Rejection (no interview): 12/20
# Preliminary interview scheduled (please specify: MLA, phone, Skype, etc.): (12/10) Zoom
# Rejection (after preliminary interview):
# Campus interview scheduled:
# Rejection (after campus interview):
# Offer made:
# Offer accepted:
# NOTES:

# %%
# Check
print(df_cw[df_cw['cw_genre']=='Other'].JobDesc.sample(n=1).iloc[0])
# Out:
# Beginning August 2019
# Liberal Arts Writing Program
# Full-Time Faculty Appointment with Benefits (multiple positions available)
# To meet the needs of an expanding academic vision and a growing student body, Ringling College is seeking qualified candidates for a full-time faculty position in the Liberal Arts Writing Program.
# The successful candidate will be responsible for teaching three courses or nine credits per semester from a menu of writing courses that may include first-year writing, Introduction to Story, Creative Writing and/or other writing electives. Ongoing commitment to creative work/scholarship in the profession is expected. Active participation with faculty, department, and college service is required.
# This is a full-time appointment with benefits. The salary will be commensurate with the candidate’s qualifications and experience. The anticipated start date is August 2019. The College has a supportive, collegial faculty, a curriculum that strongly values excellence and a robust support system dedicated to using the most current technology.
# Include evidence of: • A commitment to collaborative teaching, outreach, scholarship, and service• A demonstrated interest in art and design and in working in an art and design environment • Experience working with a diverse student population, including students for whom English is a second language • A repertoire of engaging teaching techniques that works with a variety of student learning styles• Significant creative writing in a range of reputable publications.
# Required materials include cover letter with specific qualifications for the position; resume or CV; employment and education history; contact information of three references (names, titles, email, and telephone numbers); teaching philosophy; a 15- to 20-page creative writing sample (in one or more genres, including academic writing); and, an unofficial transcript copy of the most relevant degree. Candidates may be asked to submit additional materials if needed. Official transcripts will be required upon hire. Review of applications will begin immediately.
# http://ringling.simplehire.com/postings/2194
# General questions regarding the job application process may be emailed to aamail@ringling.edu.
# Deadline: Jan 11 for full consideration (open until filled)
# Acknowledgment received:
# Request for additional materials:
# Rejection (no interview): 1/28; 3/26
# Preliminary interview scheduled (please specify: MLA, phone, Skype, etc.):
# Rejection (after preliminary interview):
# Campus interview scheduled:
# Rejection (after campus interview):
# Offer made:
# Offer accepted:
# NOTES:

# %%
## Plot
def do_plot(color_by, save_to, msg=''):
    # get date
    now=datetime.now()
    date=f'{now.year}-{now.month:02d}-{now.day:02d}'
    
    # count
    df_count=df_cw.groupby([color_by,'JobYear']).count().reset_index()
    
    # make fig
    fig=(
        p9.ggplot(p9.aes(x='JobYear',y='Count',color=color_by), df_count) 
        + p9.geom_line()
        + p9.geom_text(p9.aes(label='Count'),size=10)
        + p9.scale_x_continuous(breaks=range(2011,2021))
        + p9.ggtitle(f'Number of creative writing jobs{msg}, 2011-2020 (as of {date})')
    )
    # save
    fig.save(save_to.replace('.png',f'.{date}.png'),dpi=300)

    #return
    return fig

# %%
do_plot(
    'cw_genre',
    'figures/figmisc1.creative_writing_jobs.png',
    ' by mentions of genre'
)
# Out:
# <ggplot: (8788139187409)>

# %%
do_plot(
    'cw_genre_nonfiction',
    'figures/figmisc1.creative_writing_jobs.nonfic.png',
    ' in creative non-fiction'
)
# Out:
# <ggplot: (8788139203961)>

# %%
do_plot(
    'cw_genre_fiction',
    'figures/figmisc1.creative_writing_jobs.fiction.png',
    ' in fiction'
)
# Out:
# <ggplot: (8788136748505)>

# %%
do_plot(
    'cw_genre_poetry',
    'figures/figmisc1.creative_writing_jobs.poetry.png',
    ' in poetry'
)
# Out:
# <ggplot: (8788136567149)>
