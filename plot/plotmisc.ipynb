# %% [markdown]
# # Misc plots

# %%
import pandas as pd
import plotnine as p9
p9.options.figure_size=(11,8)
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
now=datetime.now()
date=f'{now.year}-{now.month:02d}-{now.day:02d}'

# %% [markdown]
# ## Creative non-fiction

# %%
# Load job data
df_all = pd.read_csv('../synthesis/data.jobcensus.synthesized.2021-01-12.csv')
# Load field aliases
df_alias = pd.read_csv('../synthesis/data.jobcensus.field_aliases.csv')
# Merge
df = df_all.merge(df_alias,on='JobField',how='inner')
# Clean
df['JobYear']=df['JobYear'].apply(int)
df = df[df.FieldAlias!='--']
# Show
df
# Out:
#                                                 JobTitle  JobYear  \
# 0                 Bard College (Annandale-on-Hudson, NY)     2011
# 1                        Bowdoin College (Brunswick, ME)     2011
# 2                     Boston College (Chestnut Hill, MA)     2011
# 3                      Brown University (Providence, RI)     2011
# 4             Central Methodist University (Fayette, MO)     2011
# ...                                                  ...      ...
# 14115                         Associate Professor Poetry     2020
# 14116  Assistant Professor in Asian American, Pacific...     2020
# 14117  Visiting Faculty Position in Japanese at Benni...     2020
# 14118  Professorships in Race in Art & Design (Libera...     2020
# 14119                  Assistant Professor of Portuguese     2020
#
#                                                  JobLink  JobType  \
# 0                                                    NaN       TT
# 1                                                    NaN  Unknown
# 2                                                    NaN       TT
# 3               http://chronicle.com/jobs/0000646693-01/  Unknown
# 4      http://www.higheredjobs.com/faculty/details.cf...       TT
# ...                                                  ...      ...
# 14115  https://joblist.mla.org/job-details/2761/assoc...       TT
# 14116  https://joblist.mla.org/job-details/2685/assis...       TT
# 14117  https://joblist.mla.org/job-details/2699/visit...   Non-TT
# 14118  https://joblist.mla.org/job-details/2772/profe...       TT
# 14119  https://mlajoblist-js.madgexccstage.com/job-de...       TT
#
#                     JobField JobSource  \
# 0                   Medieval      Wiki
# 1                   Medieval      Wiki
# 2                   Medieval      Wiki
# 3                   Medieval      Wiki
# 4                   Medieval      Wiki
# ...                      ...       ...
# 14115                 Poetry       JIL
# 14116                  Asian       JIL
# 14117               Japanese       JIL
# 14118  Critical Race Studies       JIL
# 14119             Portuguese       JIL
#
#                                                  JobDesc  \
# 0      Position Title: Assistant Professor\nDescripti...
# 1      From MLA JIL (November 12)\nDescription: Two-y...
# 2      Position Title: Assistant Professor\nLink: on ...
# 3      LINK\nDescription: "full professor of English ...
# 4      Position Title: Tenure-track Assistant or Asso...
# ...                                                  ...
# 14115  University of California, Irvine | English | F...
# 14116        Atlanta, GA | English | Full-time | Georgia
# 14117  Bennington, VT | Japanese | Humanities | Part-...
# 14118  Providence, Rhode Island, United States, 02903...
# 14119  US Air Force Academy, Colorado Springs, CO | P...
#
#                                             JobLink_norm      FieldAlias  \
# 0                                                    NaN        Medieval
# 1                                                    NaN        Medieval
# 2                                                    NaN        Medieval
# 3               http://chronicle.com/jobs/0000646693-01/        Medieval
# 4      http://www.higheredjobs.com/faculty/details.cf...        Medieval
# ...                                                  ...             ...
# 14115           https://joblist.mla.org/job-details/2761          Poetry
# 14116           https://joblist.mla.org/job-details/2685  Ethnic Studies
# 14117           https://joblist.mla.org/job-details/2699       Languages
# 14118           https://joblist.mla.org/job-details/2772  Ethnic Studies
# 14119  https://mlajoblist-js.madgexccstage.com/job-de...       Languages
#
#        Count
# 0        202
# 1        202
# 2        202
# 3        202
# 4        202
# ...      ...
# 14115      2
# 14116      1
# 14117      1
# 14118      1
# 14119      1
#
# [13616 rows x 10 columns]

# %%
# Creative writing?
df['FieldAlias'].value_counts()
# Out:
# Postdoc                        2568
# Rhetoric/Composition           2144
# Creative Writing               1586
# Ethnic Studies                  778
# Generalist                      718
# Gender Studies                  690
# Theatre/Drama                   615
# Early Modern                    473
# Film Studies                    428
# Anglophone/Postcolonial         366
# Community Colleges              361
# Medieval                        353
# American: C19/Early             307
# British: Modern/Contemp.        295
# New Media and DH                273
# American: C20-C21               250
# British: C19                    245
# British: C17-C18                242
# Comparative Literature          239
# British Open                    149
# American Studies                141
# Children’s Lit                  141
# Languages                        76
# Environmental Literature         47
# Regional                         33
# Critical Theory                  26
# Communication/Media Studies      26
# Jewish Studies                   25
# Translation Studies              16
# Unknown                           4
# Poetry                            1
# Name: FieldAlias, dtype: int64

# %%
df_cw = df[df['FieldAlias'] == "Creative Writing"]
df_cw
# Out:
#                                                 JobTitle  JobYear  \
# 3876                Beloit College (Poetry VAP position)     2011
# 3877             Bowling Green SU (TT Asst Prof, Poetry)     2011
# 3878                                    Brown University     2011
# 3879         California State University, San Bernardino     2011
# 3880   Columbia College Chicago - Assistant Professor...     2011
# ...                                                  ...      ...
# 13343  Early Career Fellowship in Creative Writing: R...     2020
# 13344  Assistant Professor of English and Director of...     2020
# 13345               O'Connor Fellows in Creative Writing     2020
# 13346               Open Rank - English or Related Field     2020
# 13347  Tenure Track Assistant Professor - Creative Wr...     2020
#
#                                                  JobLink  JobType  \
# 3876                         mailto:bcenglish@beloit.edu   Non-TT
# 3877   http://www.higheredjobs.com/search/details.cfm...       TT
# 3878   http://www.higheredjobs.com/faculty/details.cf...       TT
# 3879                                                 NaN       TT
# 3880                       https://employment.colum.edu/       TT
# ...                                                  ...      ...
# 13343  https://joblist.mla.org/job-details/2877/early...  Postdoc
# 13344  https://joblist.mla.org/job-details/2799/assis...       TT
# 13345  https://joblist.mla.org/job-details/2822/o-con...  Postdoc
# 13346  https://joblist.mla.org/job-details/2717/open-...       TT
# 13347  https://joblist.mla.org/job-details/2694/tenur...       TT
#
#                JobField JobSource  \
# 3876    CreativeWriting      Wiki
# 3877    CreativeWriting      Wiki
# 3878    CreativeWriting      Wiki
# 3879    CreativeWriting      Wiki
# 3880    CreativeWriting      Wiki
# ...                 ...       ...
# 13343  Creative Writing       JIL
# 13344  Creative Writing       JIL
# 13345  Creative Writing       JIL
# 13346  Creative Writing       JIL
# 13347  Creative Writing       JIL
#
#                                                  JobDesc  \
# 3876   From MLA JIL (2/25)\n2 Visiting Assistant Prof...
# 3877   HigherEd\n"Tenure-track assistant professor in...
# 3878   Higher Ed\n"Brown University invites applicati...
# 3879   From MLA JIL\n"The English Department seeks a ...
# 3880   From MLA JIL 3/18/11:\nASSISTANT PROFESSOR OF ...
# ...                                                  ...
# 13343  Austin, TX | English | Full-time | Texas | Cre...
# 13344  High Point University - High Point, NC | Engli...
# 13345  Colgate University, Hamilton, NY | English | F...
# 13346  Washington, DC | English, American Sign Langua...
# 13347  Davis, California | English | Full-time | Cali...
#
#                                             JobLink_norm        FieldAlias  \
# 3876                         mailto:bcenglish@beloit.edu  Creative Writing
# 3877   http://www.higheredjobs.com/search/details.cfm...  Creative Writing
# 3878   http://www.higheredjobs.com/faculty/details.cf...  Creative Writing
# 3879                                                 NaN  Creative Writing
# 3880                       https://employment.colum.edu/  Creative Writing
# ...                                                  ...               ...
# 13343           https://joblist.mla.org/job-details/2877  Creative Writing
# 13344           https://joblist.mla.org/job-details/2799  Creative Writing
# 13345           https://joblist.mla.org/job-details/2822  Creative Writing
# 13346           https://joblist.mla.org/job-details/2717  Creative Writing
# 13347           https://joblist.mla.org/job-details/2694  Creative Writing
#
#        Count       creative_nonfic
# 3876    1039                 Other
# 3877    1039  Creative Non-Fiction
# 3878    1039                 Other
# 3879    1039                 Other
# 3880    1039                 Other
# ...      ...                   ...
# 13343    215                 Other
# 13344    215                 Other
# 13345    215                 Other
# 13346    215                 Other
# 13347    215                 Other
#
# [1586 rows x 11 columns]

# %%
# Mark as creative non/fiction?
def mark_creative_nonfic(jobdesc):
    import re
    # lowercase
    jobdesc=jobdesc.lower()
    rgx = re.compile("(\w[\w']*\w|\w)")
    jobdesc_words=set(rgx.findall(jobdesc))
    labeld = {
        'Non-Fiction':{'non-fiction','nonfiction'},
        'Fiction':{'fiction','novel'},
        'Poetry':{'poetry'}
    }
    label = []
    for genre,lbls in labeld.items():
        if lbls & jobdesc_words:
            label.append(genre)
    labelstr='/'.join(label)
    if not labelstr: labelstr='Other'
    return labelstr

# %%
df_cw['cw_genre']=df_cw['JobDesc'].apply(mark_creative_nonfic)
df_cw['cw_genre_nonfiction']=df_cw['cw_genre'].apply(lambda x: 'Non-Fiction' if 'Non-Fiction' in x else 'Other')
df_cw['cw_genre_fiction']=df_cw['cw_genre'].apply(lambda x: 'Fiction' if 'Fiction' in x.replace('Non-Fiction','') else 'Other')
df_cw['cw_genre_poetry']=df_cw['cw_genre'].apply(lambda x: 'Poetry' if 'Poetry' in x else 'Other')
df_cw['cw_genre'].value_counts()
# Out:
# Fiction                       434
# Other                         298
# Poetry                        239
# Non-Fiction/Fiction/Poetry    184
# Fiction/Poetry                160
# Non-Fiction/Fiction           144
# Non-Fiction                    75
# Non-Fiction/Poetry             52
# Name: cw_genre, dtype: int64

# %%
# save
df_cw.to_csv('../synthesis/data.jobcensus.synthesized.2021-01-12.creative-writing.csv')

# %%
# Check
print(df_cw[df_cw['cw_genre']=='Non-Fiction'].JobDesc.sample(n=1).iloc[0])
# Out:
# The University of Nevada, Las Vegas invites applications for Assistant Professor of Literary Nonfiction (17071)
# PROFILE of the UNIVERSITY:
# UNLV is a doctoral-degree-granting institution of approximately 29,000 students and more than 3,000 faculty and staff that is classified by the Carnegie Foundation for the Advancement of Teaching as a research university with high research activity. UNLV offers a broad range of respected academic programs and is on a path to join the top tier of national public research universities. The university is committed to recruiting and retaining top students and faculty, educating the region's diversifying population and workforce, driving economic activity through increased research and community partnerships, and creating an academic health center for Southern Nevada that includes the launch of a new UNLV School of Medicine. UNLV is located on a 332-acre main campus and two satellite campuses in Southern Nevada. For more information, visit us online at: http://www.unlv.edu
# ROLE of the POSITION:
# The Department of English is searching for an Assistant Professor, tenure track, in Literary Nonfiction, broadly understood. The successful candidate will join the faculty of the established Creative Writing International program affiliated with the Black Mountain Institute, and will help to create a new Literary Nonfiction track for the M.F.A. and Ph.D. with creative dissertation.
# QUALIFICATIONS:
# This position requires an M.F.A., Ph.D., or equivalent credentials, and a significant publication record with at least one book in the field in print by a nationally recognized press. Teaching experience preferred.
# SALARY RANGE:
# Salary competitive with those at similarly situated institutions. Position is contingent upon funding.
# APPLICATION DETAILS:
# Submit a letter of interest, a detailed resume listing qualifications and experience, and the names, addresses, and telephone numbers of at least three professional references who may be contacted. Applicants should fully describe their qualifications and experience, with specific reference to each of the minimum and preferred qualifications, because this is the information on which the initial review of materials will be based.
# Although this position will remain open until filled, review of candidates' materials will begin on November 1, 2016, and best consideration will be given applications submitted by this date. Materials should be addressed to Douglas Unger, Search Committee Chair, and are to be submitted via online application at https://hrsearch.unlv.edu. For assistance with UNLV's online applicant portal, contact UNLV Employment Services at (702) 895-3504 or applicant.inquiry@unlv.edu.
# HigherEdJobs.com
# Deadline: Nov. 1 2016
# Acknowledgment received:
# Request for additional materials: 11/22 x2
# Rejection (no interview): 3/10 by email (indicated position has been filled.)
# Preliminary interview scheduled (please specify: MLA, phone, Skype, etc.):
# Rejection (after preliminary interview):
# Campus interview scheduled:
# Rejection (after campus interview):
# Offer made:
# Offer accepted:
# NOTES:
# (2/11): Is this search dead?
# (3/5) I just assumed that I didn't make to the next round, but I haven't heard anything since November.
# <span class="

# %%
# Check
print(df_cw[df_cw['cw_genre']=='Non-Fiction/Fiction'].JobDesc.sample(n=1).iloc[0])
# Out:
# The Illinois College English Department seeks applications for a Visiting Assistant Professor position in writing, beginning August 2012. The position is for one year, with a definite possibility of another year. The new faculty member will teach fiction, new media/journalistic writing, and introductory writing. Experience with other genres, such as scriptwriting, playwriting, and nonfiction is also desirable. For more information, see http://www.ic.edu/employment .
# From MLA JIL 9/15/11
# Deadline: Review of applications begins November 1, 2011, and continues until the position is filled.
# Acknowledgment received:
# Request for Additional Materials:
# Rejection Letter:
# MLA or Phone Interview scheduled: 12/16 (phone)
# Campus interview scheduled: Campus visit/interview completed. [posted 3/17]
# Offer made: 4/5
# Offer accepted: 4/10
# NOTES AND QUERIES:
# <span class="

# %%
## Plot
def do_plot(color_by, save_to, msg=''):
    # get date
    now=datetime.now()
    date=f'{now.year}-{now.month:02d}-{now.day:02d}'
    
    # count
    df_count=df_cw.groupby([color_by,'JobYear']).count().reset_index()
    
    # make fig
    fig=(
        p9.ggplot(p9.aes(x='JobYear',y='Count',color=color_by), df_count) 
        + p9.geom_line()
        + p9.geom_text(p9.aes(label='Count'),size=10)
        + p9.scale_x_continuous(breaks=range(2011,2021))
        + p9.ggtitle(f'Number of creative writing jobs{msg}, 2011-2020 (as of {date})')
    )
    # save
    fig.save(save_to.replace('.png',f'.{date}.png'),dpi=300)

    #return
    return fig

# %%
do_plot(
    'cw_genre',
    'figures/figmisc1.creative_writing_jobs.png',
    ' by mentions of genre'
)
# Out:
# <ggplot: (8785134961441)>

# %%
do_plot(
    'cw_genre_nonfiction',
    'figures/figmisc1.creative_writing_jobs.nonfic.png',
    ' in creative non-fiction'
)
# Out:
# <ggplot: (8785158701565)>

# %%
do_plot(
    'cw_genre_fiction',
    'figures/figmisc1.creative_writing_jobs.fiction.png',
    ' in fiction'
)
# Out:
# <ggplot: (8785160165449)>

# %%
do_plot(
    'cw_genre_poetry',
    'figures/figmisc1.creative_writing_jobs.poetry.png',
    ' in poetry'
)
# Out:
# <ggplot: (8785160253289)>
