# %% [markdown]
# # Synthesizing data

# %%
WIKI_FN = '../wiki/data.jobcensus.wiki.2020-11-23.csv'
MLA_FN = '../mla/data.jobcensus.mla.2020-11-23.anno.csv'

# %%
import pandas as pd,os,sys
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load data

# %%
df_wiki0 = pd.read_csv(WIKI_FN)
df_mla0 = pd.read_csv(MLA_FN)

# %%
df_wiki0['JobSource']='Wiki'
df_mla0['JobSource']='JIL'

# %% [markdown]
# ## Rename cols

# %%
df_mla = df_mla0[df_mla0.in_wiki!='y'][['title','year','link','JobType','field','JobSource']]
df_mla.columns=['JobTitle','JobYear','JobLink','JobType','JobField','JobSource']
df_mla
# Out:
#                                              JobTitle  JobYear  \
# 0   Mellon Post-Doctoral Fellowship in Latinx Lite...     2020
# 1   Early Career Fellowship in Creative Writing: R...     2020
# 2             English Education - Assistant Professor     2020
# 3   Tenure-track Assistant Professor in Rhetoric a...     2020
# 4                        Assistant Professor, English     2020
# ..                                                ...      ...
# 82  Spanish Language Murphy Visiting Fellowship in...     2020
# 83                  Assistant Professor of Portuguese     2020
# 84                     Assistant Professor of Russian     2020
# 87  Tenure Track Assistant Professor - Creative Wr...     2020
# 88                         Instructor in Human Rights     2020
#
#                                               JobLink  JobType  \
# 0   https://joblist.mla.org/job-details/2878/mello...  Postdoc
# 1   https://joblist.mla.org/job-details/2877/early...  Postdoc
# 2   https://joblist.mla.org/job-details/2747/engli...       TT
# 3   https://joblist.mla.org/job-details/2745/tenur...       TT
# 4   https://joblist.mla.org/job-details/2696/assis...       TT
# ..                                                ...      ...
# 82  https://joblist.mla.org/job-details/2880/spani...   Non-TT
# 83  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 84  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 87  https://joblist.mla.org/job-details/2694/tenur...       TT
# 88  https://joblist.mla.org/job-details/2693/instr...   Non-TT
#
#                 JobField JobSource
# 0                 Latinx       JIL
# 1       Creative Writing       JIL
# 2                  TESOL       JIL
# 3   Rhetoric/Composition       JIL
# 4             Anglophone       JIL
# ..                   ...       ...
# 82               Spanish       JIL
# 83            Portuguese       JIL
# 84               Russian       JIL
# 87      Creative Writing       JIL
# 88               Unknown       JIL
#
# [69 rows x 6 columns]

# %%
df_wiki = df_wiki0[df_wiki0.IsUni=='y'][['section_title','year','section_links','JobType','page_group','JobSource']].fillna('')
df_wiki.columns=['JobTitle','JobYear','JobLink','JobType','JobField','JobSource']
df_wiki
# Out:
#                                          JobTitle  JobYear  \
# 10         Bard College (Annandale-on-Hudson, NY)     2011
# 11                Bowdoin College (Brunswick, ME)     2011
# 12             Boston College (Chestnut Hill, MA)     2011
# 13              Brown University (Providence, RI)     2011
# 14     Central Methodist University (Fayette, MO)     2011
# ...                                           ...      ...
# 15648                   Johns Hopkins University.     2020
# 15649           University of Portland (USA:OR).      2020
# 15650     University of British Columbia (Canada)     2020
# 15651           University of Portland (USA:OR).      2020
# 15652  California State University San Bernardino     2020
#
#                                                  JobLink  JobType  \
# 10                                                             TT
# 11                                                        Unknown
# 12                                                             TT
# 13              http://chronicle.com/jobs/0000646693-01/  Unknown
# 14     http://www.higheredjobs.com/faculty/details.cf...       TT
# ...                                                  ...      ...
# 15648                 https://apply.interfolio.com/80430  Unknown
# 15649  https://jobs.chronicle.com/job/288460/associat...       TT
# 15650                                                          TT
# 15651  https://jobs.chronicle.com/job/288460/associat...       TT
# 15652  https://www.schooljobs.com/careers/csusb/jobs/...       TT
#
#                       JobField JobSource
# 10                    Medieval      Wiki
# 11                    Medieval      Wiki
# 12                    Medieval      Wiki
# 13                    Medieval      Wiki
# 14                    Medieval      Wiki
# ...                        ...       ...
# 15648           Jewish Studies      Wiki
# 15649           Jewish Studies      Wiki
# 15650           Jewish Studies      Wiki
# 15651  Native American Studies      Wiki
# 15652  Native American Studies      Wiki
#
# [14241 rows x 6 columns]

# %%
df_wiki[(df_wiki.JobYear==2020) & (df_wiki.JobField=='Comparative Literature')]
# Out:
#                                    JobTitle  JobYear  \
# 15529          UC Berkeley (Berkeley, CA).      2020
# 15530        Université de Caen (FRA:CAL).      2020
# 15531  Cambridge University (Cambridge, UK)     2020
# 15532   Stanford University (Stanford, CA).     2020
#
#                                                  JobLink  JobType  \
# 15529            https://aprecruit.berkeley.edu/JPF02679       TT
# 15530          https://euraxess.ec.europa.eu/jobs/537836  Unknown
# 15531              https://www.jobs.cam.ac.uk/job/27641/  Unknown
# 15532  https://gender.stanford.edu/fellowships/postdo...  Unknown
#
#                      JobField JobSource
# 15529  Comparative Literature      Wiki
# 15530  Comparative Literature      Wiki
# 15531  Comparative Literature      Wiki
# 15532  Comparative Literature      Wiki

# %% [markdown]
# ### Clean links

# %%
df_mla['JobLink_norm']=df_mla.JobLink.apply(lambda x: '/'.join(x.split('/')[:-2]))
# df_mla.JobLink_norm.value_counts()

# %%
def clean_wiki_links(x):
    for l in str(x).split(' | '):
        if 'joblist.mla.org' in l:
            return '/'.join(l.split('/')[:-2])
    return x
df_wiki['JobLink_norm']=df_wiki['JobLink'].apply(clean_wiki_links)
# df_wiki.JobLink_norm.value_counts()

# %% [markdown]
# ### Find overlap

# %%
df_all = df_wiki.append(df_mla)
df_all
# Out:
#                                              JobTitle  JobYear  \
# 10             Bard College (Annandale-on-Hudson, NY)     2011
# 11                    Bowdoin College (Brunswick, ME)     2011
# 12                 Boston College (Chestnut Hill, MA)     2011
# 13                  Brown University (Providence, RI)     2011
# 14         Central Methodist University (Fayette, MO)     2011
# ..                                                ...      ...
# 82  Spanish Language Murphy Visiting Fellowship in...     2020
# 83                  Assistant Professor of Portuguese     2020
# 84                     Assistant Professor of Russian     2020
# 87  Tenure Track Assistant Professor - Creative Wr...     2020
# 88                         Instructor in Human Rights     2020
#
#                                               JobLink  JobType  \
# 10                                                          TT
# 11                                                     Unknown
# 12                                                          TT
# 13           http://chronicle.com/jobs/0000646693-01/  Unknown
# 14  http://www.higheredjobs.com/faculty/details.cf...       TT
# ..                                                ...      ...
# 82  https://joblist.mla.org/job-details/2880/spani...   Non-TT
# 83  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 84  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 87  https://joblist.mla.org/job-details/2694/tenur...       TT
# 88  https://joblist.mla.org/job-details/2693/instr...   Non-TT
#
#             JobField JobSource  \
# 10          Medieval      Wiki
# 11          Medieval      Wiki
# 12          Medieval      Wiki
# 13          Medieval      Wiki
# 14          Medieval      Wiki
# ..               ...       ...
# 82           Spanish       JIL
# 83        Portuguese       JIL
# 84           Russian       JIL
# 87  Creative Writing       JIL
# 88           Unknown       JIL
#
#                                          JobLink_norm
# 10
# 11
# 12
# 13           http://chronicle.com/jobs/0000646693-01/
# 14  http://www.higheredjobs.com/faculty/details.cf...
# ..                                                ...
# 82           https://joblist.mla.org/job-details/2880
# 83  https://mlajoblist-js.madgexccstage.com/job-de...
# 84  https://mlajoblist-js.madgexccstage.com/job-de...
# 87           https://joblist.mla.org/job-details/2694
# 88           https://joblist.mla.org/job-details/2693
#
# [14310 rows x 7 columns]

# %%
# sanity check: should be 4 -->
# df_all[(df_all.JobField=='Comparative Literature') & (df_all.JobYear==2020)]

# %% [markdown]
# ## Save field names

# %%
# Download names
field_alias_fn = 'data.jobcensus.field_aliases.csv'
if not os.path.exists(field_alias_fn):
    df_aliases=df_all.JobField.value_counts().reset_index()
    df_aliases.columns=['JobField','Count']
    df_aliases['FieldAlias']=df_aliases['JobField']
    df_aliases[['JobField','FieldAlias','Count']].sort_values('JobField').to_csv(field_alias_fn,index=False)

# %%
# Edit them!

# %% [markdown]
# # Save

# %%
now=datetime.now()
date=f'{now.year}-{now.month}-{now.day}'
ofn=f'data.jobcensus.synthesized.{date}.csv'
df_all.to_csv(ofn,index=False)
