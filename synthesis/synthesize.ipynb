# %% [markdown]
# # Synthesizing data

# %%
WIKI_FN = '../wiki/data.jobcensus.wiki.2021-01-12.csv'
MLA_FN = '../mla/data.jobcensus.mla.2020-11-23.anno.csv'

# %%
import pandas as pd,os,sys
from datetime import datetime
import warnings,re
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load data

# %%
df_wiki0 = pd.read_csv(WIKI_FN)
df_mla0 = pd.read_csv(MLA_FN)

# %%
df_wiki0['JobSource']='Wiki'
df_mla0['JobSource']='JIL'

# %% [markdown]
# ## Rename cols

# %%
df_mla = df_mla0[df_mla0.in_wiki!='y'][['title','year','link','JobType','field','JobSource','desc']]
df_mla.columns=['JobTitle','JobYear','JobLink','JobType','JobField','JobSource','JobDesc']
df_mla
# Out:
#                                              JobTitle  JobYear  \
# 0   Mellon Post-Doctoral Fellowship in Latinx Lite...     2020
# 1   Early Career Fellowship in Creative Writing: R...     2020
# 2             English Education - Assistant Professor     2020
# 3   Tenure-track Assistant Professor in Rhetoric a...     2020
# 4                        Assistant Professor, English     2020
# ..                                                ...      ...
# 82  Spanish Language Murphy Visiting Fellowship in...     2020
# 83                  Assistant Professor of Portuguese     2020
# 84                     Assistant Professor of Russian     2020
# 87  Tenure Track Assistant Professor - Creative Wr...     2020
# 88                         Instructor in Human Rights     2020
#
#                                               JobLink  JobType  \
# 0   https://joblist.mla.org/job-details/2878/mello...  Postdoc
# 1   https://joblist.mla.org/job-details/2877/early...  Postdoc
# 2   https://joblist.mla.org/job-details/2747/engli...       TT
# 3   https://joblist.mla.org/job-details/2745/tenur...       TT
# 4   https://joblist.mla.org/job-details/2696/assis...       TT
# ..                                                ...      ...
# 82  https://joblist.mla.org/job-details/2880/spani...   Non-TT
# 83  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 84  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 87  https://joblist.mla.org/job-details/2694/tenur...       TT
# 88  https://joblist.mla.org/job-details/2693/instr...   Non-TT
#
#                 JobField JobSource  \
# 0                 Latinx       JIL
# 1       Creative Writing       JIL
# 2                  TESOL       JIL
# 3   Rhetoric/Composition       JIL
# 4             Anglophone       JIL
# ..                   ...       ...
# 82               Spanish       JIL
# 83            Portuguese       JIL
# 84               Russian       JIL
# 87      Creative Writing       JIL
# 88               Unknown       JIL
#
#                                               JobDesc
# 0   Williamstown, MA | English | Full-time | Massa...
# 1   Austin, TX | English | Full-time | Texas | Cre...
# 2   Fresno, CA | English | English education | Ful...
# 3   Boston College, Chestnut Hill Massachusetts 02...
# 4   http://employment.govst.edu/postings/5442 | En...
# ..                                                ...
# 82  Conway, AR | English, Spanish | Full-time | Ar...
# 83  US Air Force Academy, Colorado Springs, CO | P...
# 84  US Air Force Academy, Colorado Springs, CO | L...
# 87  Davis, California | English | Full-time | Cali...
# 88       Chicago, IL | English | Full-time | Illinois
#
# [69 rows x 7 columns]

# %%
# df_wiki0[(df_wiki0.page_group=='Ethnic Studies') & (df_wiki0.IsUni!='y')]

# %%
df_wiki = df_wiki0[df_wiki0.IsUni=='y'][['section_title','year','section_links','JobType','page_group','JobSource','section_content']].fillna('')
df_wiki.columns=['JobTitle','JobYear','JobLink','JobType','JobField','JobSource','JobDesc']
df_wiki
# Out:
#                                                 JobTitle  JobYear  \
# 3                   Generalist & Non-National Categories     2011
# 4                        AY 2011-12 English Lit Salaries     2011
# 5                                               See Also     2011
# 10                Bard College (Annandale-on-Hudson, NY)     2011
# 11                       Bowdoin College (Brunswick, ME)     2011
# ...                                                  ...      ...
# 15540                  University of Portland (USA:OR).      2020
# 15541         California State University San Bernardino     2020
# 15542                           Centre College (USA: KY)     2020
# 15543            Clarkson University (Potsdam, NY, USA).     2020
# 15544  Nova Southeastern University (Fort Lauderdale,...     2020
#
#                                                  JobLink  JobType  \
# 3      https://www.wikia.org/ | https://www.wikia.org...  Unknown
# 4                                                              TT
# 5      http://chronicle.com/article/Average-Faculty-S...  Unknown
# 10                                                             TT
# 11                                                        Unknown
# ...                                                  ...      ...
# 15540  https://jobs.chronicle.com/job/288460/associat...       TT
# 15541  https://www.schooljobs.com/careers/csusb/jobs/...       TT
# 15542                 https://apply.interfolio.com/82668       TT
# 15543  https://www.higheredjobs.com/institution/detai...       TT
# 15544  https://nsucareers.nova.edu/en-us/job/498244/f...       TT
#
#                       JobField JobSource  \
# 3           English Literature      Wiki
# 4         English Lit Salaries      Wiki
# 5         English Lit Salaries      Wiki
# 10                    Medieval      Wiki
# 11                    Medieval      Wiki
# ...                        ...       ...
# 15540  Native American Studies      Wiki
# 15541  Native American Studies      Wiki
# 15542  Native American Studies      Wiki
# 15543  Native American Studies      Wiki
# 15544  Native American Studies      Wiki
#
#                                                  JobDesc
# 3      Community Colleges\nComparative Literature\nCr...
# 4      Public state university (R2), Midwest. Tenure-...
# 5      See also: English Lit Salaries 2010-2011 & Eng...
# 10     Position Title: Assistant Professor\nDescripti...
# 11     From MLA JIL (November 12)\nDescription: Two-y...
# ...                                                  ...
# 15540  University of Portland (USA:OR). Associate Pro...
# 15541  California State University San Bernardino (US...
# 15542  Centre College (USA: KY) Post-Doctoral Fellows...
# 15543  Clarkson University (Potsdam, NY, USA). Assist...
# 15544  Nova Southeastern University (Fort Lauderdale,...
#
# [14804 rows x 7 columns]

# %%
# df_wiki[(df_wiki.JobYear==2020) & (df_wiki.JobField=='Comparative Literature')]

# %%
#df_wiki[df_wiki.JobField=='Ethnic Studies']

# %% [markdown]
# ### Clean links

# %%
df_mla['JobLink_norm']=df_mla.JobLink.apply(lambda x: '/'.join(x.split('/')[:-2]))
# df_mla.JobLink_norm.value_counts()

# %%
def clean_wiki_links(x):
    for l in str(x).split(' | '):
        if 'joblist.mla.org' in l:
            return '/'.join(l.split('/')[:-2])
    return x
df_wiki['JobLink_norm']=df_wiki['JobLink'].apply(clean_wiki_links)
# df_wiki.JobLink_norm.value_counts()

# %% [markdown]
# ### Find overlap

# %%
df_all = df_wiki.append(df_mla)
df_all
# Out:
#                                              JobTitle  JobYear  \
# 3                Generalist & Non-National Categories     2011
# 4                     AY 2011-12 English Lit Salaries     2011
# 5                                            See Also     2011
# 10             Bard College (Annandale-on-Hudson, NY)     2011
# 11                    Bowdoin College (Brunswick, ME)     2011
# ..                                                ...      ...
# 82  Spanish Language Murphy Visiting Fellowship in...     2020
# 83                  Assistant Professor of Portuguese     2020
# 84                     Assistant Professor of Russian     2020
# 87  Tenure Track Assistant Professor - Creative Wr...     2020
# 88                         Instructor in Human Rights     2020
#
#                                               JobLink  JobType  \
# 3   https://www.wikia.org/ | https://www.wikia.org...  Unknown
# 4                                                           TT
# 5   http://chronicle.com/article/Average-Faculty-S...  Unknown
# 10                                                          TT
# 11                                                     Unknown
# ..                                                ...      ...
# 82  https://joblist.mla.org/job-details/2880/spani...   Non-TT
# 83  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 84  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 87  https://joblist.mla.org/job-details/2694/tenur...       TT
# 88  https://joblist.mla.org/job-details/2693/instr...   Non-TT
#
#                 JobField JobSource  \
# 3     English Literature      Wiki
# 4   English Lit Salaries      Wiki
# 5   English Lit Salaries      Wiki
# 10              Medieval      Wiki
# 11              Medieval      Wiki
# ..                   ...       ...
# 82               Spanish       JIL
# 83            Portuguese       JIL
# 84               Russian       JIL
# 87      Creative Writing       JIL
# 88               Unknown       JIL
#
#                                               JobDesc  \
# 3   Community Colleges\nComparative Literature\nCr...
# 4   Public state university (R2), Midwest. Tenure-...
# 5   See also: English Lit Salaries 2010-2011 & Eng...
# 10  Position Title: Assistant Professor\nDescripti...
# 11  From MLA JIL (November 12)\nDescription: Two-y...
# ..                                                ...
# 82  Conway, AR | English, Spanish | Full-time | Ar...
# 83  US Air Force Academy, Colorado Springs, CO | P...
# 84  US Air Force Academy, Colorado Springs, CO | L...
# 87  Davis, California | English | Full-time | Cali...
# 88       Chicago, IL | English | Full-time | Illinois
#
#                                          JobLink_norm
# 3   https://www.wikia.org/ | https://www.wikia.org...
# 4
# 5   http://chronicle.com/article/Average-Faculty-S...
# 10
# 11
# ..                                                ...
# 82           https://joblist.mla.org/job-details/2880
# 83  https://mlajoblist-js.madgexccstage.com/job-de...
# 84  https://mlajoblist-js.madgexccstage.com/job-de...
# 87           https://joblist.mla.org/job-details/2694
# 88           https://joblist.mla.org/job-details/2693
#
# [14873 rows x 8 columns]

# %%
# drop duplicates
df_all=df_all.drop_duplicates(['JobTitle','JobYear','JobLink'])
df_all
# Out:
#                                              JobTitle  JobYear  \
# 3                Generalist & Non-National Categories     2011
# 4                     AY 2011-12 English Lit Salaries     2011
# 5                                            See Also     2011
# 10             Bard College (Annandale-on-Hudson, NY)     2011
# 11                    Bowdoin College (Brunswick, ME)     2011
# ..                                                ...      ...
# 82  Spanish Language Murphy Visiting Fellowship in...     2020
# 83                  Assistant Professor of Portuguese     2020
# 84                     Assistant Professor of Russian     2020
# 87  Tenure Track Assistant Professor - Creative Wr...     2020
# 88                         Instructor in Human Rights     2020
#
#                                               JobLink  JobType  \
# 3   https://www.wikia.org/ | https://www.wikia.org...  Unknown
# 4                                                           TT
# 5   http://chronicle.com/article/Average-Faculty-S...  Unknown
# 10                                                          TT
# 11                                                     Unknown
# ..                                                ...      ...
# 82  https://joblist.mla.org/job-details/2880/spani...   Non-TT
# 83  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 84  https://mlajoblist-js.madgexccstage.com/job-de...       TT
# 87  https://joblist.mla.org/job-details/2694/tenur...       TT
# 88  https://joblist.mla.org/job-details/2693/instr...   Non-TT
#
#                 JobField JobSource  \
# 3     English Literature      Wiki
# 4   English Lit Salaries      Wiki
# 5   English Lit Salaries      Wiki
# 10              Medieval      Wiki
# 11              Medieval      Wiki
# ..                   ...       ...
# 82               Spanish       JIL
# 83            Portuguese       JIL
# 84               Russian       JIL
# 87      Creative Writing       JIL
# 88               Unknown       JIL
#
#                                               JobDesc  \
# 3   Community Colleges\nComparative Literature\nCr...
# 4   Public state university (R2), Midwest. Tenure-...
# 5   See also: English Lit Salaries 2010-2011 & Eng...
# 10  Position Title: Assistant Professor\nDescripti...
# 11  From MLA JIL (November 12)\nDescription: Two-y...
# ..                                                ...
# 82  Conway, AR | English, Spanish | Full-time | Ar...
# 83  US Air Force Academy, Colorado Springs, CO | P...
# 84  US Air Force Academy, Colorado Springs, CO | L...
# 87  Davis, California | English | Full-time | Cali...
# 88       Chicago, IL | English | Full-time | Illinois
#
#                                          JobLink_norm
# 3   https://www.wikia.org/ | https://www.wikia.org...
# 4
# 5   http://chronicle.com/article/Average-Faculty-S...
# 10
# 11
# ..                                                ...
# 82           https://joblist.mla.org/job-details/2880
# 83  https://mlajoblist-js.madgexccstage.com/job-de...
# 84  https://mlajoblist-js.madgexccstage.com/job-de...
# 87           https://joblist.mla.org/job-details/2694
# 88           https://joblist.mla.org/job-details/2693
#
# [14074 rows x 8 columns]

# %%
# sanity check: should be 4 -->
# df_all[(df_all.JobField=='Comparative Literature') & (df_all.JobYear==2020)]

# %% [markdown]
# ## Prune out unknowns

# %%
def get_jobtype(title,link=''):
    title=title.lower()
    rgx = re.compile("(\w[\w']*\w|\w)")
    title_words=rgx.findall(title)
    if 'post-doc' in title or 'postdoc' in title: return 'Postdoc'
    if 'visiting' in title: return 'Non-TT'
    if 'professor' in title or 'open-rank' in title: return 'TT'
    if 'fellowship' in title or 'fellow' in title: return 'Postdoc'
    if 'adjunct' in title or 'part-time' in title: return 'Non-TT'
    if 'director' in title: return 'Non-TT'
    if 'instructor' in title or 'freelance' in title: return 'Non-TT'
    if 'vap' in title_words: return 'Non-TT'
    if 'lecturer' in title: return 'Non-TT'
    if link: return get_jobtype_from_mla(link)
    return 'Unknown'

# %%
# Fix missing job type errors
df_all['JobType']=[get_jobtype(x) if y=='Unknown' else y
                    for x,y in zip(df_all['JobTitle'],df_all['JobType'])]#.apply(get_jobtype)

# %%
df_all[df_all.JobType=='Unknown']
# Out:
#                                    JobTitle  JobYear  \
# 3      Generalist & Non-National Categories     2011
# 5                                  See Also     2011
# 11          Bowdoin College (Brunswick, ME)     2011
# 13        Brown University (Providence, RI)     2011
# 25           Hebrew University of Jerusalem     2011
# ...                                     ...      ...
# 15525                       Duke University     2020
# 15526                Texas State University     2020
# 15527                      Williams College     2020
# 15529             San José State University     2020
# 15534             Johns Hopkins University.     2020
#
#                                                  JobLink  JobType  \
# 3      https://www.wikia.org/ | https://www.wikia.org...  Unknown
# 5      http://chronicle.com/article/Average-Faculty-S...  Unknown
# 11                                                        Unknown
# 13              http://chronicle.com/jobs/0000646693-01/  Unknown
# 25            http://www.hum.huji.ac.il/new.php?cat=3223  Unknown
# ...                                                  ...      ...
# 15525                                                     Unknown
# 15526                                                     Unknown
# 15527                                                     Unknown
# 15529                                                     Unknown
# 15534                 https://apply.interfolio.com/80430  Unknown
#
#                          JobField JobSource  \
# 3              English Literature      Wiki
# 5            English Lit Salaries      Wiki
# 11                       Medieval      Wiki
# 13                       Medieval      Wiki
# 25                       Medieval      Wiki
# ...                           ...       ...
# 15525  Chicanx %26 Latinx Studies      Wiki
# 15526  Chicanx %26 Latinx Studies      Wiki
# 15527  Chicanx %26 Latinx Studies      Wiki
# 15529  Chicanx %26 Latinx Studies      Wiki
# 15534              Jewish Studies      Wiki
#
#                                                  JobDesc  \
# 3      Community Colleges\nComparative Literature\nCr...
# 5      See also: English Lit Salaries 2010-2011 & Eng...
# 11     From MLA JIL (November 12)\nDescription: Two-y...
# 13     LINK\nDescription: "full professor of English ...
# 25     Title: Assistant/Associate/Full professor of E...
# ...                                                  ...
# 15525                                    Duke University
# 15526            Texas State University (San Marcos, TX)
# 15527                Williams College (Williamstown, MA)
# 15529           San José State University (San José, CA)
# 15534  Johns Hopkins University. Lecturer (full-time)...
#
#                                             JobLink_norm
# 3      https://www.wikia.org/ | https://www.wikia.org...
# 5      http://chronicle.com/article/Average-Faculty-S...
# 11
# 13              http://chronicle.com/jobs/0000646693-01/
# 25            http://www.hum.huji.ac.il/new.php?cat=3223
# ...                                                  ...
# 15525
# 15526
# 15527
# 15529
# 15534                 https://apply.interfolio.com/80430
#
# [542 rows x 8 columns]

# %% [markdown]
# ## Save field names

# %%
# Download names
field_alias_fn = 'data.jobcensus.field_aliases.csv'
if not os.path.exists(field_alias_fn):
    df_aliases=df_all.JobField.value_counts().reset_index()
    df_aliases.columns=['JobField','Count']
    df_aliases['FieldAlias']=df_aliases['JobField']
    df_aliases[['JobField','FieldAlias','Count']].sort_values('JobField').to_csv(field_alias_fn,index=False)

# %%
# Edit them!

# %% [markdown]
# # Save

# %%
now=datetime.now()
date=f'{now.year}-{now.month:02d}-{now.day:02d}'
ofn=f'data.jobcensus.synthesized.{date}.csv'
df_all.to_csv(ofn,index=False)
